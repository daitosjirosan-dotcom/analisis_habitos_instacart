# %% [markdown]
# # ¡Hola Gato! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class='alert alert-block alert-success'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class='alert alert-block alert-warning'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class='alert alert-block alert-danger'>
#
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
#
#
#
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
#
#
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión v1 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Hola Gato, ¿cómo estás? Espero que todo esté bien por tu lado.
#
# Felicitaciones por completar todos los items del notebook, veo bastante trabajo a lo largo de este. En general, está todo correcto y con una buena aplicación del código necesario para lograr los objetivos. Tan solo resta que corrijas el gráfico de la sección A4, el resultado necesario a presentar es diferente, te dejé en comentarios lo necesario a modificar.
#
# Si tienes dudas o preguntas, me las puedes dejar en comentario azul, con gusto las responderé en la siguiente iteración.
#
# Saludos!
#
#
# </div>

# %% [markdown]
# ## Resumen de la revisión v2 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2 </b> <a class="tocSkip"></a>
#
# Bien hecho Gato, buen trabajo con las últimas correcciones. Has terminado completamente las tareas necesarias del notebook, no tengo comentarios de corrección adicionales, tu proyecto está aprobado. Los conocimientos que aplicaste aquí te serán muy útiles para análisis futuros, mucho éxito!
#
# Saludos!
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
import pandas as pd

# %%
orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')

# %%
products = pd.read_csv('/datasets/products.csv', sep=';')

# %%
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')

# %%
departments = pd.read_csv('/datasets/departments.csv', sep=';')

# %%
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor         </b> <a class="tocSkip"></a>
#
# Correcto. Bien hecho al importar la data usando el parámetro `sep=;"` para que la lectura de los datos se pueda realizar correctamente.
#
#
# </div>

# %%
print('------orders--------')
print(orders.head())
print('------products--------')
print(products.head())
print('-----aisles----------')
print(aisles.head())
print('------departments--------')
print(departments.head())
print('------order_products--------')
print(order_products.head())
# Out:
# ------orders--------
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0
# ------products--------
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# ...

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
col_id = None
for col in orders.columns:
    if 'order' in col and 'id' in col:
        col_id = col
        break

if col_id:
    duplicados = orders.duplicated(subset=col_id, keep=False)
    num_duplicados = duplicados.sum()
    print(f"Número de pedidos duplicados (por '{col_id}'): {num_duplicados}")

    if num_duplicados > 0:
        print("\nPedidos duplicados:")
        display(orders[duplicados].sort_values(col_id))
    else:
        print(" No hay pedidos duplicados en el DataFrame.")
else:
    print(" No se encontró ninguna columna que parezca ser 'order_id'.")
# Out:
# Número de pedidos duplicados (por 'order_id'): 30
#
# Pedidos duplicados:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 354993    391768    57671            19          3                  2
# 371905    391768    57671            19          3                  2
# 119251    408114    68324             4          3                  2
# 321100    408114    68324             4          3                  2
# 394347    467134    63189            21          3                  2
# 250626    467134    63189            21          3                  2
# 99462     794638    50898            24          3                  2
# 145574    794638    50898            24          3                  2
# 311713   1021560    53767             3          3                  2
# 242618   1021560    53767             3          3                  2
# 164581   1112182   202304            84          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
pedidos_miercoles_2am = orders[
    (orders['order_dow'] == 3) & 
    (orders['order_hour_of_day'] == 2)
]

print(f"Total de pedidos realizados el miércoles a las 2:00 a.m.: {len(pedidos_miercoles_2am)}")
pedidos_miercoles_2am.head()
# Out:
# Total de pedidos realizados el miércoles a las 2:00 a.m.: 121
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
# 18420    382357   120200            19          3                  2
# 24691    690242    77357             2          3                  2
#
#        days_since_prior_order
# 4838                     16.0
# 5156                     11.0
# 15506                     7.0
# 18420                    11.0
# 24691                     9.0

# %% [markdown]
# ¿Qué sugiere este resultado?

# %%
# Elimina los pedidos duplicados
orders = orders.drop_duplicates(keep='first')

# %%
duplicados_restantes = orders.duplicated(subset='order_id', keep=False)
num_duplicados_restantes = duplicados_restantes.sum()

print(f"Número de filas duplicadas restantes: {num_duplicados_restantes}")
if num_duplicados_restantes > 0:
    print("\n Aún existen duplicados. Ejemplo de los duplicados encontrados:")
    display(orders[duplicados_restantes].sort_values('order_id').head(10))
else:
    print("No hay filas duplicadas en el DataFrame.")
# Out:
# Número de filas duplicadas restantes: 0
# No hay filas duplicadas en el DataFrame.

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
duplicados_id = orders.duplicated(subset='order_id', keep=False)

num_duplicados_id = duplicados_id.sum()
print(f"Número de order_id duplicados: {num_duplicados_id}")
if num_duplicados_id > 0:
    print("\n Ejemplos de order_id duplicados:")
    display(orders[duplicados_id].sort_values('order_id').head(10))
else:
    print(" No hay IDs de pedidos duplicados en el DataFrame.")
# Out:
# Número de order_id duplicados: 0
#  No hay IDs de pedidos duplicados en el DataFrame.

# %%
# e creado esta celda para escribir me equivoque 3 veces a la hora de borrar duplicados devido a que borraba cosas especificas y no todo lo duplicado de golpe XD

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Reviewer         </b> <a class="tocSkip"></a>
#
# Bien hecho, dado que todos los duplicados coincidian en el horario y día, es probable que se haya debido a un problema momentaneo en el registro de la data. En un entorno profesional, sería importante revisar que este problema no afecte a muchos registros y ver con el área responsable si esto es un problema conocido o no.
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
duplicados_products = products.duplicated(keep=False)

num_duplicados_products = duplicados_products.sum()

print(f"Número de filas duplicadas en 'products': {num_duplicados_products}")

if num_duplicados_products > 0:
    print("\nEjemplos de filas duplicadas:")
    display(products[duplicados_products].sort_values(by=products.columns.tolist()).head(10))
else:
    print("No hay filas duplicadas en el DataFrame 'products'.")
# Out:
# Número de filas duplicadas en 'products': 0
# No hay filas duplicadas en el DataFrame 'products'.

# %%
duplicados_product_id = products.duplicated(subset='product_id', keep=False)

# Contar cuántos IDs de producto están duplicados
num_duplicados_product_id = duplicados_product_id.sum()

print(f"Número de product_id duplicados: {num_duplicados_product_id}")

# Mostrar algunos ejemplos si existen duplicados
if num_duplicados_product_id > 0:
    print("\nEjemplos de product_id duplicados:")
    display(products[duplicados_product_id].sort_values('product_id').head(10))
else:
    print(" No hay IDs de productos duplicados en el DataFrame 'products'.")
# Out:
# Número de product_id duplicados: 0
#  No hay IDs de productos duplicados en el DataFrame 'products'.

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
nombres_mayus = products['product_name'].str.upper()

duplicados_nombres = nombres_mayus.duplicated(keep=False)

num_duplicados_nombres = duplicados_nombres.sum()

print(f"Número de nombres de productos duplicados (ignorando mayúsculas/minúsculas): {num_duplicados_nombres}")
if num_duplicados_nombres > 0:
    print("\nEjemplos de nombres duplicados:")
    display(products[duplicados_nombres].sort_values('product_name').head(10))
else:
    print(" No hay nombres de productos duplicados en el DataFrame 'products'.")
# Out:
# Número de nombres de productos duplicados (ignorando mayúsculas/minúsculas): 1465
#
# Ejemplos de nombres duplicados:
#        product_id                               product_name  aisle_id  \
# 31844       31845  18-In-1 Hemp Peppermint Pure-Castile Soap        25
# 23339       23340  18-in-1 Hemp Peppermint Pure-Castile Soap        25
# 19941       19942            Aged Balsamic Vinegar Of Modena        19
# 13152       13153            Aged Balsamic Vinegar of Modena        19
# 22582       22583         Albacore Solid White Tuna In Water        95
# 24830       24831         Albacore Solid White Tuna in Water        95
# 515           516                     American Cheese Slices        21
# 9037         9038                     American Cheese slices        21
# 49530       49531               Anchovy Fillets In Olive Oil        95
# 12325       12326               Anchovy Fillets in Olive Oil        95
#
#        department_id
# 31844             11
# 23339             11
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes
duplicados = products['product_name'].duplicated(keep=False)  
resultados = products[duplicados]

print("Productos con nombres duplicados:")
print(resultados[['product_id', 'product_name', 'aisle_id', 'department_id']])
# Out:
# Productos con nombres duplicados:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
# Para esta parte es mejor no quitar los duplicados en nombre. Nota que ninguna fila está duplicada de forma completa, es decir, tienen diferente id de producto. Es posible que sean diferentes versiones de un mismo producto, por lo que no es necesario eliminarlos.
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>ya decia yo por que mas abajo no aparecia ningun duplicado cuando los estaba quitando me fijare mas para no poner un proceso donde no va.</b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %%
#los duplicados fueron encontrados y quitados del proceso para que no ocurran percanses futuros

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
duplicados_department_id = departments.duplicated(subset='department_id', keep=False)

# Contar cuántos IDs están duplicados
num_duplicados_department_id = duplicados_department_id.sum()

print(f"Número de department_id duplicados: {num_duplicados_department_id}")

# Mostrar algunos ejemplos si existen duplicados
if num_duplicados_department_id > 0:
    print("\nEjemplos de department_id duplicados:")
    display(departments[duplicados_department_id].sort_values('department_id').head(10))
else:
    print(" No hay IDs de departamentos duplicados en el DataFrame 'departments'.")
# Out:
# Número de department_id duplicados: 0
#  No hay IDs de departamentos duplicados en el DataFrame 'departments'.

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
duplicados_department_id = departments.duplicated(subset='department_id', keep=False)

num_duplicados_department_id = duplicados_department_id.sum()
print(f"Número de department_id duplicados: {num_duplicados_department_id}")

if num_duplicados_department_id > 0:
    print("\nEjemplos de department_id duplicados:")
    display(departments[duplicados_department_id].sort_values('department_id').head(10))
else:
    print(" No hay IDs de departamentos duplicados en el DataFrame 'departments'.")
# Out:
# Número de department_id duplicados: 0
#  No hay IDs de departamentos duplicados en el DataFrame 'departments'.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %%
#los duplicados no existen o fueron eliminados en procesos anteriores

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
duplicados_aisles = aisles.duplicated(keep=False)
num_duplicados_aisles = duplicados_aisles.sum()
print(f"Número de filas duplicadas en 'aisles': {num_duplicados_aisles}")
if num_duplicados_aisles > 0:
    print("\nEjemplos de filas duplicadas:")
    display(aisles[duplicados_aisles].sort_values(by=aisles.columns.tolist()))
else:
    print(" No hay filas duplicadas en el DataFrame 'aisles'.")
# Out:
# Número de filas duplicadas en 'aisles': 0
#  No hay filas duplicadas en el DataFrame 'aisles'.

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
duplicados_aisle_id = aisles.duplicated(subset='aisle_id', keep=False)

num_duplicados_aisle_id = duplicados_aisle_id.sum()

print(f"Número de aisle_id duplicados: {num_duplicados_aisle_id}")

if num_duplicados_aisle_id > 0:
    print("\nEjemplos de aisle_id duplicados:")
    display(aisles[duplicados_aisle_id].sort_values('aisle_id').head(10))
else:
    print(" No hay IDs de pasillos duplicados en el DataFrame 'aisles'.")
# Out:
# Número de aisle_id duplicados: 0
#  No hay IDs de pasillos duplicados en el DataFrame 'aisles'.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %%
#los duplicados no existen o fueron eliminados en procesos anteriores. esto ya va muy bien tal vez demaciado bien...

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
duplicados_order_products = order_products.duplicated(keep=False)
num_duplicados_order_products = duplicados_order_products.sum()
print(f"Número de filas duplicadas en 'order_products': {num_duplicados_order_products}")

if num_duplicados_order_products > 0:
    print("\nEjemplos de filas duplicadas:")
    display(order_products[duplicados_order_products].sort_values(by=order_products.columns.tolist()).head(10))
else:
    print(" No hay filas duplicadas en el DataFrame 'order_products'.")
# Out:
# Número de filas duplicadas en 'order_products': 0
#  No hay filas duplicadas en el DataFrame 'order_products'.

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
duplicados_completos = order_products.duplicated(keep=False)
num_duplicados_completos = duplicados_completos.sum()
print(f"Número de filas totalmente duplicadas: {num_duplicados_completos}")

duplicados_clave = order_products.duplicated(subset=['order_id', 'product_id'], keep=False)
num_duplicados_clave = duplicados_clave.sum()
print(f"Número de duplicados por combinación (order_id, product_id): {num_duplicados_clave}")

if num_duplicados_clave > 0:
    print("\nEjemplos de duplicados por (order_id, product_id):")
    display(order_products[duplicados_clave].sort_values(['order_id', 'product_id']).head(10))
else:
    print(" No hay duplicados engañosos en 'order_products'.")
# Out:
# Número de filas totalmente duplicadas: 0
# Número de duplicados por combinación (order_id, product_id): 0
#  No hay duplicados engañosos en 'order_products'.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %%
#ok o yo la estoy haciendo mal o cuando estaba borrando mas arriba borre los duplicados de los demas asumire lo segundo ya que no veo errores tembien son como las 3:00am y la falta de sueño me esta pegando

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Buen trabajo en esta sección con la revisión de duplicados
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
valores_ausentes = products['product_name'].isna()

num_ausentes = valores_ausentes.sum()
print(f"Número de valores ausentes en 'product_name': {num_ausentes}")

if num_ausentes > 0:
    print("\nEjemplos de filas con 'product_name' ausente:")
    display(products[valores_ausentes].head(10))
else:
    print(" No hay valores ausentes en la columna 'product_name'.")
# Out:
# Número de valores ausentes en 'product_name': 1258
#
# Ejemplos de filas con 'product_name' ausente:
#      product_id product_name  aisle_id  department_id
# 37           38          NaN       100             21
# 71           72          NaN       100             21
# 109         110          NaN       100             21
# 296         297          NaN       100             21
# 416         417          NaN       100             21
# 436         437          NaN       100             21
# 439         440          NaN       100             21
# 471         472          NaN       100             21
# 490         491          NaN       100             21
# 555         556          NaN       100             21

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
#no se exactamente por que estan relacionados todos con el id 100 (en todos estare probando codigo para ver)
productos_sin_nombre = products[products['product_name'].isna()]
aisles_ausentes = productos_sin_nombre['aisle_id'].unique()
print(f"IDs de pasillo para productos sin nombre: {aisles_ausentes}")
todos_aisle_100 = all(aisles_ausentes == 100)
print(f"\n¿Todos los productos ausentes están en el pasillo con ID 100? {todos_aisle_100}")
# Out:
# IDs de pasillo para productos sin nombre: [100]
#
# ¿Todos los productos ausentes están en el pasillo con ID 100? True

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
#no se exactamente por que estan relacionados todos con el 21 pero es interesante cuanto menos
productos_sin_nombre = products[products['product_name'].isna()]
departamentos_ausentes = productos_sin_nombre['department_id'].unique()
print(f"IDs de departamento para productos sin nombre: {departamentos_ausentes}")
todos_department_21 = all(departamentos_ausentes == 21)
print(f"\n¿Todos los productos ausentes están en el departamento con ID 21? {todos_department_21}")
# Out:
# IDs de departamento para productos sin nombre: [21]
#
# ¿Todos los productos ausentes están en el departamento con ID 21? True

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
pasillo_100 = aisles[aisles['aisle_id'] == 100]
departamento_21 = departments[departments['department_id'] == 21]

print("Datos del pasillo con ID 100:")
print(pasillo_100)

print("\nDatos del departamento con ID 21:")
print(departamento_21)
# Out:
# Datos del pasillo con ID 100:
#     aisle_id    aisle
# 99       100  missing
#
# Datos del departamento con ID 21:
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'].fillna('Unknown', inplace=True)

print("\nValores ausentes después de completar:")
print(products['product_name'].isnull().sum())

print("\nPrimeras 5 filas del DataFrame de productos:")
print(products.head())
# Out:
# Valores ausentes después de completar:
# 0
#
# Primeras 5 filas del DataFrame de productos:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, debe haber sido un error específico al registrar los datos de ese pasillo y departamento
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
valores_ausentes = orders.isnull().sum()

print("Valores ausentes en el DataFrame 'orders':")
print(valores_ausentes[valores_ausentes > 0])
# Out:
# Valores ausentes en el DataFrame 'orders':
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
valores_ausentes = orders[orders['days_since_prior_order'].isnull()]
no_primer_pedido = valores_ausentes[valores_ausentes['order_number'] > 1]
print("Valores ausentes en 'days_since_prior_order' que no son el primer pedido del cliente:")
print(no_primer_pedido)
# Out:
# Valores ausentes en 'days_since_prior_order' que no son el primer pedido del cliente:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %%
# perimero se busco los valores ausentes y luego fueron prosesados en procesos anteriores

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien, es normal que esas filas tengan nulos, son los primeros pedidos de los clientes, y entonces no hay días desde un pedido anterior porque no existe ese pedido anterior.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
valores_ausentes = order_products.isnull().sum()

print("Valores ausentes en el DataFrame 'order_products':")
print(valores_ausentes[valores_ausentes > 0])
# Out:
# Valores ausentes en el DataFrame 'order_products':
# add_to_cart_order    836
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
valor_minimo = order_products['product_id'].min()
valor_maximo = order_products['product_id'].max()

print(f"Valor mínimo en 'product_id': {valor_minimo}")
print(f"Valor máximo en 'product_id': {valor_maximo}")
# Out:
# Valor mínimo en 'product_id': 1
# Valor máximo en 'product_id': 49694

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# aca no se si deveria eliminar los ausentes ya que no me dice que lo haga pero quitando eso todo lo demas que es encontrar los valores y encontrar los valores maximos y minimos fueron encontrados

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
ids_con_valores_ausentes = order_products[order_products['add_to_cart_order'].isnull()]['order_id']

lista_ids_ausentes = ids_con_valores_ausentes.tolist()

print(f"Cantidad de IDs de pedidos con valores ausentes en 'add_to_cart_order': {len(lista_ids_ausentes)}")
print("Primeros 5 IDs de pedidos con valores ausentes:", lista_ids_ausentes[:5])
# Out:
# Cantidad de IDs de pedidos con valores ausentes en 'add_to_cart_order': 836
# Primeros 5 IDs de pedidos con valores ausentes: [2449164, 1968313, 2926893, 1717990, 1959075]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
ids_con_valores_ausentes = order_products[order_products['add_to_cart_order'].isnull()]['order_id']

conteo_productos_por_pedido = order_products.groupby('order_id')['product_id'].count()

conteo_productos_ausentes = conteo_productos_por_pedido[conteo_productos_por_pedido.index.isin(ids_con_valores_ausentes)]

minimo_conteo = conteo_productos_ausentes.min()

print(f"Valor mínimo del conteo de productos para pedidos con valores ausentes: {minimo_conteo}")

if minimo_conteo > 64:
    print("Todos los pedidos con valores ausentes tienen más de 64 productos.")
else:
    print("No todos los pedidos con valores ausentes tienen más de 64 productos.")
# Out:
# Valor mínimo del conteo de productos para pedidos con valores ausentes: 65
# Todos los pedidos con valores ausentes tienen más de 64 productos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Bien hecho, es probable que el sistema no permita más de 64 tipos de productos en esa columna, por lo que no guarda nada después
#
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
#El análisis indica que, en un conjunto de datos, se observó que los pedidos con valores faltantes (ausentes) en alguna información específica, tienen una característica común:
#Conteo mínimo: Todos estos pedidos contienen al menos 65 productos.
#Conclusión: Esto sugiere que los pedidos con información incompleta tienden a ser de mayor volumen, ya que siempre superan el límite de 64 productos.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
print(order_products.columns.tolist())

if 'add_to_cart?' in order_products.columns:
    if order_products['add_to_cart?'].isnull().sum() > 0:
        print("Hay valores faltantes en la columna 'add_to_cart?'")
        order_products['add_to_cart?'] = order_products['add_to_cart?'].fillna(999)
    order_products['add_to_cart?'] = order_products['add_to_cart?'].astype(int)
else:
    print("La columna 'add_to_cart?' no existe en el DataFrame.")
# Out:
# ['order_id', 'product_id', 'add_to_cart_order', 'reordered']
# La columna 'add_to_cart?' no existe en el DataFrame.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %%
#la columna 'add_to_cart?' no existe por lo que no puedo hacer mucho con ello pero si existe ['order_id', 'product_id', 'add_to_cart_order', 'reordered'] 
#la verdad no se si me equivoque ni en que parte fue pero solo me queda esperar a que me corrigan si existe un paso que me alla saltado

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
if 'order_hour_of_day' in orders.columns:
    if orders['order_hour_of_day'].between(0, 23).all():
        print("Todos los valores en 'order_hour_of_day' son razonables (0-23).")
    else:
        print("Hay valores en 'order_hour_of_day' que están fuera del rango (0-23).")
else:
    print("La columna 'order_hour_of_day' no existe en el DataFrame.")

if 'order_dow' in orders.columns:
    if orders['order_dow'].between(0, 6).all():
        print("Todos los valores en 'order_dow' son razonables (0-6).")
    else:
        print("Hay valores en 'order_dow' que están fuera del rango (0-6).")
else:
    print("La columna 'order_dow' no existe en el DataFrame.")
# Out:
# Todos los valores en 'order_hour_of_day' son razonables (0-23).
# Todos los valores en 'order_dow' son razonables (0-6).

# %%
# pidireon que verificara que los valores fueran razonables para poder trabajar con ellos

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto, muy bien con el cálculo. Ahora estamos seguros que tenemos datos que hacen sentido en estas columnas.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
pedidos_por_hora = orders.groupby('order_hour_of_day').size()
pedidos_por_hora = pedidos_por_hora.sort_index()
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
pedidos_por_hora.plot(kind='bar', color='skyblue')
plt.title('Número de Pedidos por Hora del Día')
plt.xlabel('Hora del Día (0-23)')
plt.ylabel('Número de Pedidos')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones

# %%
#me pidieron hacer un grafico de la relacion de los numeros de pedidos y las horas del dia en las que se hicieron
#yo asumo que es para saber cuales son las horas con mas movimiento de pedidos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
#
# Bien hecho con este gráfico, se observa que hay pedidos nocturnos y el peak llega a las 10 de la mañana
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
compras_por_dia = orders['order_dow'].value_counts().sort_index()
dias_semana = {
    0: 'Lunes',
    1: 'Martes',
    2: 'Miércoles',
    3: 'Jueves',
    4: 'Viernes',
    5: 'Sábado',
    6: 'Domingo'
}
compras_por_dia = compras_por_dia.reindex(dias_semana.keys())
compras_por_dia.index = dias_semana.values()
plt.figure(figsize=(10, 6))
sns.barplot(x=compras_por_dia.index, y=compras_por_dia.values, palette='viridis')
plt.title('Número de Compras por Día de la Semana', fontsize=16)
plt.xlabel('Día de la Semana', fontsize=12)
plt.ylabel('Número de Compras', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Correcto el gráfico, se aprecia que el domingo es el día con mayor cantidad de pedidos. Salvo el lunes, el resto de los días son muy parejos.
#
#
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones

# %%
#me pidieron crear un grafico que muestre los dias mas activos 
#asumo que como pasa con el grafico anterior a este es para ver que dias son los mas activos

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
conteo_dias = orders['days_since_prior_order'].value_counts().sort_index()
plt.figure(figsize=(12, 6)) 
conteo_dias.plot(kind='bar', color='skyblue')
plt.title('Distribución de Pedidos por Días desde el Pedido Anterior')
plt.xlabel('Días desde el Pedido Anterior')
plt.ylabel('Número de Pedidos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout() 
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones

# %%
#El mapa de barrars mostrará la frecuencia de pedidos para cada combinación de hora del día y día de la semana.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
# El mapa de calor que muestras es útil para comparar cada día y las horas de ventas. Sin embargo, en esta parte, se requiere ver como es la variable de días entre pedidos, es decir, la cantidad de días desde que hace un pedido hasta que hace el siguiente. Esto está en la columna *days_since_prior_order*, para mostrar sus valores te recomiendo agrupar esa variable, contar la cantidad de pedidos y luego graficar el resultado en un gráfico de barras.
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>creo que lo arregle creo.</b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, el gráfico es correcto. Nota que el tiempo de 30 días es muy alto, esto es sospechoso ya que es el valor más grande que se registra y es anormalmente grande respecto a los valores que vienen justo antes. Probablemente se debe a que el sistema no registra más de 30 días entre compras y todas las que son de más de ese tiempo las guarda como 30.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
import matplotlib.pyplot as plt

# %%
wednesday_dow = 2

wednesday_orders = orders[orders['order_dow'] == wednesday_dow]

wednesday_hour_counts = wednesday_orders['order_hour_of_day'].value_counts().sort_index()

all_hours = pd.Index(range(0, 24))

wednesday_hour_counts = wednesday_hour_counts.reindex(all_hours, fill_value=0)

plt.figure(figsize=(10, 6))
plt.bar(wednesday_hour_counts.index, wednesday_hour_counts.values, color='skyblue')
plt.title('Distribución de Pedidos - Miércoles')
plt.xlabel('Hora del Día (0-23)')
plt.ylabel('Número de Pedidos')
plt.xticks(all_hours)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
saturday_dow = 5

saturday_orders = orders[orders['order_dow'] == saturday_dow]

saturday_hour_counts = saturday_orders['order_hour_of_day'].value_counts().sort_index()

saturday_hour_counts = saturday_hour_counts.reindex(all_hours, fill_value=0)

plt.figure(figsize=(10, 6))
plt.bar(saturday_hour_counts.index, saturday_hour_counts.values, color='lightcoral')
plt.title('Distribución de Pedidos - Sábado')
plt.xlabel('Hora del Día (0-23)')
plt.ylabel('Número de Pedidos')
plt.xticks(all_hours)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#en esta ocacion se a creado 2 graficas para dias espesificos como lo son el miercoles y el sabado
#por lo que vemos aca el miercoles es un poco mas activo que el sabado

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien con la comparación entre los días
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
import matplotlib.pyplot as plt
orders_per_customer = orders.groupby('user_id')['order_id'].count()
customer_order_counts = orders_per_customer.value_counts().sort_index()
plt.figure(figsize=(12, 7))
plt.bar(customer_order_counts.index, customer_order_counts.values, color='teal')

plt.title('Distribución del Número de Órdenes por Cliente', fontsize=16)
plt.xlabel('Número de Órdenes Realizadas por Cliente', fontsize=12)
plt.ylabel('Número de Clientes', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#aca podemos ver que en el grafico Eje X: Representa el número de órdenes que un cliente ha realizado.
#Eje Y: Representa el número de clientes que han realizado esa cantidad específica de órdenes.
#con eso en cuenta la cantidad de clientes que hacen de 1 a 5 odernes es muy alta

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
# Excelente, muy bien con el resultado. Observamos que la cantidad de pedidos de cliente es decreciente.
#
#
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
product_counts = order_products['product_id'].value_counts().reset_index()
product_counts.columns = ['product_id', 'order_count']
top_20_products_ids = product_counts.head(20)
top_20_with_names = pd.merge(top_20_products_ids, products[['product_id', 'product_name']], on='product_id', how='inner')
print("Los 20 productos más pedidos son:")
print(top_20_with_names[['product_id', 'product_name', 'order_count']])
# Out:
# Los 20 productos más pedidos son:
#     product_id              product_name  order_count
# 0        24852                    Banana        66050
# 1        13176    Bag of Organic Bananas        53297
# 2        21137      Organic Strawberries        37039
# 3        21903      Organic Baby Spinach        33971
# 4        47209      Organic Hass Avocado        29773
# 5        47766           Organic Avocado        24689
# 6        47626               Large Lemon        21495
# 7        16797              Strawberries        20018
# 8        26209                     Limes        19690
# 9        27845        Organic Whole Milk        19600
# 10       27966       Organic Raspberries        19197
# 11       22935      Organic Yellow Onion        15898
# 12       24964            Organic Garlic        15292
# 13       45007          Organic Zucchini        14584
# 14       39275       Organic Blueberries        13879
# 15       49683            Cucumber Kirby        13675
# ...

# %%
#elimine uno de los espacios que iba arriba de este ya que no era necesario
#aca podemos ver que los productos mas pedidos son bananas y sus bariantes organicas(que si me preguntas a mi saben igual pero hay personas y personas)

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto,  se ve que predominan los productos orgánicos y de uso diario
#
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
articulos_por_pedido = order_products.groupby('order_id')['product_id'].count().reset_index()
articulos_por_pedido.columns = ['order_id', 'num_articulos']
estadisticas = articulos_por_pedido['num_articulos'].describe()
print(estadisticas)
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: num_articulos, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(articulos_por_pedido['num_articulos'], bins=range(1, articulos_por_pedido['num_articulos'].max() + 1), alpha=0.7)
plt.title('Distribución de artículos por pedido')
plt.xlabel('Número de artículos')
plt.ylabel('Frecuencia')
plt.show()

# %%
#aca podemos ver que el 75% de los pedidos tienen 14 artículos o menos.
# 50% de los pedidos tienen 8 artículos o menos.
#y el 25% de los pedidos tienen 5 artículos o menos.

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor      </b> <a class="tocSkip"></a>
#
# Muy bien con el gráfico, está correcto. Vemos que hay una distribución concentrada en los primeros valores, pero luego cae muy rápido
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
order_products_merged = pd.merge(order_products, products, on='product_id', how='left')
reordered_products = order_products_merged[order_products_merged['reordered'] == 1]
product_counts = reordered_products.groupby('product_name')['product_id'].agg(['count', 'first']).reset_index()
product_counts.columns = ['product_name', 'reorder_count', 'product_id']
top_20_reordered = product_counts.sort_values(by='reorder_count', ascending=False).head(20)
print(top_20_reordered[['product_name', 'product_id', 'reorder_count']])
# Out:
#                    product_name  product_id  reorder_count
# 2506                     Banana       24852          55763
# 2362     Bag of Organic Bananas       13176          44450
# 22964      Organic Strawberries       21137          28639
# 20476      Organic Baby Spinach       21903          26233
# 21637      Organic Hass Avocado       47209          23629
# 20447           Organic Avocado       47766          18743
# 23409        Organic Whole Milk       27845          16251
# 15928               Large Lemon       47626          15044
# 22501       Organic Raspberries       27966          14748
# 30881              Strawberries       16797          13945
# 16647                     Limes       26209          13327
# 23480      Organic Yellow Onion       22935          11145
# 21404            Organic Garlic       24964          10411
# 23511          Organic Zucchini       45007          10076
# 8309             Cucumber Kirby       49683           9538
# ...

# %%
# dos celdas que estaban arriba de esta fueron borradas
#aca podemos ver el top 20 pedidos que vuelven a pedirse aca podemos ver a las bananas(o platanos)
#junto a otros como Organic Avocado(oro verde le dicen algunos)

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, vemos que los productos más pedidos también son los más reordenados
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
order_products['product_id'] = order_products['product_id'].astype(str)
products['product_id'] = products['product_id'].astype(str)

df_combined = pd.merge(order_products, products, on='product_id', how='left')

total_pedidos_por_producto = df_combined.groupby('product_name')['order_id'].count().reset_index()
total_pedidos_por_producto.columns = ['product_name', 'total_pedidos']

reordered_counts = df_combined[df_combined['reordered'] == 1].groupby('product_name')['order_id'].count().reset_index()
reordered_counts.columns = ['product_name', 'veces_reordenado']

proporcion_df = pd.merge(total_pedidos_por_producto, reordered_counts, on='product_name', how='left')

proporcion_df['veces_reordenado'] = proporcion_df['veces_reordenado'].fillna(0)

proporcion_df['proporcion_reorden'] = proporcion_df['veces_reordenado'] / proporcion_df['total_pedidos']

proporcion_final = proporcion_df[['product_name', 'total_pedidos', 'veces_reordenado', 'proporcion_reorden']]
print(proporcion_final.head(10))
# Out:
#                                       product_name  total_pedidos  \
# 0                                #2 Coffee Filters            110
# 1                     #2 Cone White Coffee Filters              2
# 2                            #2 Mechanical Pencils              3
# 3                  #4 Natural Brown Coffee Filters             39
# 4           & Go! Hazelnut Spread + Pretzel Sticks             15
# 5    (70% Juice!) Mountain Raspberry Juice Squeeze              4
# 6     +Energy Black Cherry Vegetable & Fruit Juice              7
# 7          0 Calorie Acai Raspberry Water Beverage             12
# 8         0 Calorie Fuji Apple Pear Water Beverage             24
# 9  0 Calorie Strawberry Dragonfruit Water Beverage             23
#
#    veces_reordenado  proporcion_reorden
# 0              28.0            0.254545
# 1               0.0            0.000000
# 2               0.0            0.000000
# 3              14.0            0.358974
# ...

# %%
#una celda fue eliminada arriba de esta
#aca podemos ver un top 10 de los productos que vuelven a carro de compra

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, correcto. También se puede usar la media de `reordered` para este cálculo.
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
order_products['order_id'] = order_products['order_id'].astype(str)
orders['order_id'] = orders['order_id'].astype(str)

df_combined = pd.merge(order_products, orders, on='order_id', how='left')
user_product_history = df_combined.groupby('user_id')['product_id'].apply(list).reset_index()
user_product_history.columns = ['user_id', 'all_products_bought']
user_grouped = df_combined.groupby('user_id')

customer_proportions = []

for user_id, group in user_grouped:
   
    history_set = set(group['product_id'].unique())

    user_orders = group.groupby('order_id')

    total_products_in_current_orders = 0
    reordered_products_in_current_orders = 0

    for order_id, order_items in user_orders:
        total_products_in_current_orders += len(order_items)

        reordered_products_in_current_orders += order_items['reordered'].sum()

    if total_products_in_current_orders > 0 and len(user_orders) > 1: 
       
        proportion = reordered_products_in_current_orders / total_products_in_current_orders
    else:
        proportion = 0.0 

    customer_proportions.append({'user_id': user_id, 'proportion_reordered_items': proportion})


customer_reorder_proportion_df = pd.DataFrame(customer_proportions)

print(customer_reorder_proportion_df.head(10))
# Out:
#    user_id  proportion_reordered_items
# 0        2                    0.038462
# 1        4                    0.000000
# 2        5                    0.000000
# 3        6                    0.000000
# 4        7                    0.928571
# 5       11                    0.000000
# 6       12                    0.000000
# 7       13                    0.565217
# 8       14                    0.360656
# 9       15                    0.538462

# %%
#aca podemos ver la proporcion de objetos que ya a pedido antes
#creo que me pase y aca deveria haber añadido mas celdas para distribuirlo todo pero no estoy seguro

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
#
# Bien, correcto el resultado del cálculo, aunque no era necesario iterar sobre los usuarios. Otra forma de realizar el cálculo es, después del merge, realizar un group by de usuarios y realizar un conteo como hiciste, pero a nivel grupal, tal como en la parte anterior.
#
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
first_items_in_cart = order_products[order_products['add_to_cart_order'] == 1]

first_item_counts = first_items_in_cart['product_id'].value_counts().reset_index()
first_item_counts.columns = ['product_id', 'count']

first_item_counts['product_id'] = first_item_counts['product_id'].astype(str)
products['product_id'] = products['product_id'].astype(str)

first_items_with_names = pd.merge(first_item_counts, products[['product_id', 'product_name']], on='product_id', how='left')

top_20_first_items = first_items_with_names.head(20)

print("Los 20 principales artículos añadidos primero al carrito:")
print(top_20_first_items[['product_name', 'product_id', 'count']])
# Out:
# Los 20 principales artículos añadidos primero al carrito:
#                    product_name product_id  count
# 0                        Banana      24852  15562
# 1        Bag of Organic Bananas      13176  11026
# 2            Organic Whole Milk      27845   4363
# 3          Organic Strawberries      21137   3946
# 4          Organic Hass Avocado      47209   3390
# 5          Organic Baby Spinach      21903   3336
# 6               Organic Avocado      47766   3044
# 7                  Spring Water      19660   2336
# 8                  Strawberries      16797   2308
# 9           Organic Raspberries      27966   2024
# 10   Sparkling Water Grapefruit      44632   1914
# 11          Organic Half & Half      49235   1797
# 12                  Large Lemon      47626   1737
# 13                         Soda        196   1733
# 14     Organic Reduced Fat Milk      38689   1397
# 15                        Limes      26209   1370
# 16                Hass Avocados      12341   1340
# ...

# %%
# aca podemos ver los articolos que son puestos los primeros en los carros de los consumidores
#mucho fan de platano si me preguntan a mi

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Buen trabajo. Al parecer los productos orgánicos representan el grueso de ventas en varios aspectos
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### Conclusion general del proyecto:

# %%
#en este proyecto lleve acabo la organizacion y edicion de multiples data frames
#en ellos encontramos cosas como los id de los productos y donde se encuentran
#tambien se realizaron varios graficos para poder expresar la informacion de manera mas practica
#ya por ultimo estube viendo cosas como cuales productos fueron los mas pedidos
#cuales productos vuelven al carro con mas frecuencia
#tambien vimos que que dias de las semana hay mas trafico de objetos

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
# Ok con las conclusiones, pero en esta sección recuerda mencionar un resumen breve de lo realizado en el proyecto (qué data se analizó, qué se modificó) y además cuáles son los principales hallazgos, qué se encontró de interesante. Sería ideal que incluyeses alguna métrica (porcentaje, cantidad) de lo más relevante.
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>lo tendre mas encuenta para poder entregar una respuesta mas detallada y mas completa en futuros proyectos.</b> <a class='tocSkip'></a>
# </div>
